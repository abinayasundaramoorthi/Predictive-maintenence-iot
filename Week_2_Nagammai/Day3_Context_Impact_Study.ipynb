# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\delta\\Predictive-maintenence-iot\\dataset\\ai4i2020.csv")
df.head()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Machine failure', y='Air temperature [K]', data=df)
plt.title("Air Temperature vs Machine Failure")
plt.savefig("air_temp_impact.png")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Machine failure', y='Process temperature [K]', data=df)
plt.title("Process Temperature vs Machine Failure")
plt.savefig("process_temp_impact.png")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Machine failure', y='Tool wear [min]', data=df)
plt.title("Tool Wear vs Machine Failure")
plt.savefig("toolwear_impact.png")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Machine failure', y='Torque [Nm]', data=df)
plt.title("Torque vs Machine Failure")
plt.savefig("torque_impact.png")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot( x='Type', hue='Machine failure', data=df)
plt.title("Machine Type vs Failure")
plt.savefig("type_failure_impact.png")
plt.show()

# %%
failure_rate = pd.crosstab( df['Type'], df['Machine failure'], normalize='index') * 100
failure_rate

# %%
summary = pd.DataFrame({
    "Variable":[
        "Air Temperature",
        "Process Temperature",
        "Torque",
        "Tool Wear",
        "Machine Type"
    ],
    "Impact":[
        "Low",
        "Low",
        "Moderate",
        "Moderate",
        "Low"
    ]
})
summary

# %%
summary.to_csv( "context_impact_summary.csv",index=False)
print("Summary exported successfully")
