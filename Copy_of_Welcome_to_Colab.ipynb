# %% [markdown]
# <a href="https://colab.research.google.com/github/abinayasundaramoorthi/Predictive-maintenence-iot/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New section

# %% [markdown]
# #Step 1-
#  **Import** **libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %% [markdown]
# # Step 2
# **Load your Dataset**

# %%
df = pd.read_csv("/content/predictive_maintenance.csv")
print("Dataset loaded!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10187/2502510677.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/predictive_maintenance.csv")
#       2 print("Dataset loaded!")
#
# ...

# %% [markdown]
# # Step 3
# **Check** **shape**

# %%
print("Shape of dataset:", df.shape)
# This tells you how many rows and columns you have
# Out:
# Shape of dataset: (10000, 10)

# %% [markdown]
# # Step 4
# **Check columns**

# %%
print("Columns:", df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10187/1029623682.py in <cell line: 0>()
# ----> 1 print("Columns:", df.columns.tolist())
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Step 5
# **Summary of the dataset**

# %%
# Basic info - data types, null values
df.info()

# Statistical summary - mean, min, max etc.
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# ...
