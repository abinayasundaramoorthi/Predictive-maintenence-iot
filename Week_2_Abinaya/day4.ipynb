# %% [markdown]
# # Day 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run day3.ipynb
# Out:
# Dataset loaded
# Rows: 10000
# Columns: 19
# Duplicates: 0
# Missing Values: 0
# Validation Passed
# Timestamp validation passed
# Context validation passed
# Pipeline completed
# Rows: 100
# Columns: 19
# Duplicates: 0
# Missing Values: 0
# Validation Passed
# Timestamp validation passed
# Context validation passed

# %%
df = pd.read_csv("fusion_pipeline_output.csv", parse_dates=["timestamp"])
df.shape
# Out:
# (10000, 19)

# %%
def calculate_quality_score(df):
    missing_score = (1-(df.isnull().sum().sum()/(len(df) * len(df.columns)))) * 100
    duplicate_score = (1 - (df.duplicated().sum() /len(df))) * 100
    quality_score = (missing_score * 0.5 + duplicate_score * 0.5)  
    return round(quality_score, 2)
score = calculate_quality_score(merged_df)
print("Fusion Quality Score:", score)
# Out:
# Fusion Quality Score: 100.0

# %%
print("Rows in fused dataset:", len(df))
print("Expected rows (original dataset):", 10000)
# Out:
# Rows in fused dataset: 10000
# Expected rows (original dataset): 10000

# %%
print("Null timestamps:", df["timestamp"].isnull().sum())
print("Duplicate timestamps:", df["timestamp"].duplicated().sum())
print("Timestamps sorted:", df["timestamp"].is_monotonic_increasing)
# Out:
# Null timestamps: 0
# Duplicate timestamps: 0
# Timestamps sorted: True

# %%
df.isnull().sum()
# Out:
# timestamp                  0
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# shift                      0
# production_load            0
# power_quality_index        0
# maintenance_window         0
# operator_experience        0
# wear_load_index            0
# temperature_gap            0
# power_stress_score         0
# dtype: int64

# %%
print("Fully duplicated rows:", df.duplicated().sum())
# Out:
# Fully duplicated rows: 0

# %%
df.groupby("Target")[["production_load","power_quality_index","operator_experience"]].mean()
# Out:
#         production_load  power_quality_index  operator_experience
# Target
# 0              0.797746             0.925691             3.042439
# 1              0.795322             0.925337             2.964602

# %%
validate_data(df)
# Out:
# Rows: 10000
# Columns: 19
# Duplicates: 0
# Missing Values: 0
# Validation Passed
# Timestamp validation passed
# Context validation passed

# %%
bad_df = df.copy()
bad_df.loc[0, "timestamp"] = None
try:
    validate_data(bad_df)
except ValueError as e:
    print("Caught expected error:", e)
# Out:
# Rows: 10000
# Columns: 19
# Duplicates: 0
# Missing Values: 1
# Validation Failed
# Caught expected error: Null timestamps detected

# %%
bad_df2 = df.copy()
bad_df2.loc[0, "production_load"] = 1.5  # out of valid 0-1 range
try:
    validate_data(bad_df2)
except ValueError as e:
    print("Caught expected error:", e)
# Out:
# Rows: 10000
# Columns: 19
# Duplicates: 0
# Missing Values: 0
# Validation Passed
# Timestamp validation passed
# Caught expected error: production_load out of range

# %%
bad_df = df.copy()
bad_df.loc[0, "timestamp"] = None
try:
    validate_data(bad_df)
except ValueError as e:
    print("Caught expected error:", e)
# Out:
# Rows: 10000
# Columns: 19
# Duplicates: 0
# Missing Values: 1
# Validation Failed
# Caught expected error: Null timestamps detected
