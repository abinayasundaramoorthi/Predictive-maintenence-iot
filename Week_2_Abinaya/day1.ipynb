# %% [markdown]
# ##Day 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ABINAYA\Downloads\predictive_maintenance.csv")

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df["timestamp"] = pd.date_range(start="2025-01-01 00:00:00",periods=len(df),freq="h")

# %%
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type  \
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure
#
#             timestamp
# 0 2025-01-01 00:00:00
# 1 2025-01-01 01:00:00
# ...

# %%
columns= ['timestamp'] + [col for col in df.columns if col != 'timestamp']

# %%
df = df[columns]

# %%
df.head()
# Out:
#             timestamp  UDI Product ID Type  Air temperature [K]  \
# 0 2025-01-01 00:00:00    1     M14860    M                298.1
# 1 2025-01-01 01:00:00    2     L47181    L                298.2
# 2 2025-01-01 02:00:00    3     L47182    L                298.1
# 3 2025-01-01 03:00:00    4     L47183    L                298.2
# 4 2025-01-01 04:00:00    5     L47184    L                298.2
#
#    Process temperature [K]  Rotational speed [rpm]  Torque [Nm]  \
# 0                    308.6                    1551         42.8
# 1                    308.7                    1408         46.3
# 2                    308.5                    1498         49.4
# 3                    308.6                    1433         39.5
# 4                    308.7                    1408         40.0
#
#    Tool wear [min]  Target Failure Type
# 0                0       0   No Failure
# 1                3       0   No Failure
# 2                5       0   No Failure
# ...

# %%
print("Duplicate timestamps:",df["timestamp"].duplicated().sum())
# Out:
# Duplicate timestamps: 0

# %%
print(df['timestamp'].isnull().sum())
# Out:
# 0

# %%
is_sorted = df["timestamp"].is_monotonic_increasing
print(is_sorted)
# Out:
# True

# %%
df.to_csv("predictive_maintainence_timestamp.csv",index=False)
