# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("dataset/ai4i2020.csv")

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Air temperature [K]'], bins=30)
plt.title('Air Temperature Distribution')
plt.xlabel('Temperature (K)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Torque [Nm]'], bins=30)
plt.title('Torque Distribution')
plt.xlabel('Torque (Nm)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Rotational speed [rpm]'], bins=30)
plt.title('RPM Distribution')
plt.xlabel('RPM')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Tool wear [min]'], bins=30)
plt.title('Tool Wear Distribution')
plt.xlabel('Tool Wear (minutes)')
plt.ylabel('Frequency')
plt.show()

# %%
df[['Air temperature [K]',
    'Torque [Nm]',
    'Rotational speed [rpm]',
    'Tool wear [min]']].describe()
# Out:
#        Air temperature [K]   Torque [Nm]  Rotational speed [rpm]  \
# count         10000.000000  10000.000000            10000.000000
# mean            300.004930     39.986910             1538.776100
# std               2.000259      9.968934              179.284096
# min             295.300000      3.800000             1168.000000
# 25%             298.300000     33.200000             1423.000000
# 50%             300.100000     40.100000             1503.000000
# 75%             301.500000     46.800000             1612.000000
# max             304.500000     76.600000             2886.000000
#
#        Tool wear [min]
# count     10000.000000
# mean        107.951000
# std          63.654147
# min           0.000000
# 25%          53.000000
# 50%         108.000000
# 75%         162.000000
# max         253.000000
